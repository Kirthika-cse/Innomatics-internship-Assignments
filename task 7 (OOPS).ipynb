# %% [markdown]
# ###  Problem 1:  Smart Light Controller

# %%
class SmartLight:
    def __init__(self, light_name):
        self.light_name = light_name
        self.status = "OFF"   # Default status
    
    def turn_on(self):
        self.status = "ON"
    
    def turn_off(self):
        self.status = "OFF"
    
    def display_status(self):
        print(f"{self.light_name} is {self.status}")


# Sample Execution
light = SmartLight("Bedroom Light")
light.turn_on()
light.display_status()
# Out:
# Bedroom Light is ON

# %% [markdown]
# ### Problem 2: Employee ID Card System

# %%
class Employee:
    def __init__(self, name, emp_id, department):
        self.name = name
        self.emp_id = emp_id
        self.department = department
    
    def display_id_card(self):
        print("Employee ID Card")
        print(f"Name: {self.name}")
        print(f"ID: {self.emp_id}")
        print(f"Department: {self.department}")


# Sample Execution
employee = Employee("Kirthika ", "EMP1044", "IT")
employee.display_id_card()
# Out:
# Employee ID Card
# Name: Kirthika
# ID: EMP1044
# Department: IT

# %% [markdown]
# ### Problem 3: Mobile Contact Record

# %%
class Contact:
    def __init__(self, contact_name, phone_number):
        self.contact_name = contact_name
        self.phone_number = phone_number
    
    def save_contact(self):
        print("Contact Saved")
        print(f"Name: {self.contact_name}")
        print(f"Phone: {self.phone_number}")


# Sample Execution
contact = Contact("KEERTHANA", "967645258")
contact.save_contact()
# Out:
# Contact Saved
# Name: KEERTHANA
# Phone: 967645258

# %% [markdown]
# ### Problem 4: Product Price Tag Generator

# %%
class Product:
    def __init__(self, product_name, price):
        self.product_name = product_name
        self.price = price
    
    def display_price_tag(self):
        print(f"Product: {self.product_name}")
        print(f"Price: ₹{self.price}")


# Sample Execution
product = Product("EAR BUDS", 3599)
product.display_price_tag()
# Out:
# Product: EAR BUDS
# Price: ₹3599

# %% [markdown]
# ### Problem 5: Movie Rating Display System

# %%
class Movie:
    def __init__(self, movie_name, rating):
        self.movie_name = movie_name
        self.rating = rating
    
    def display_movie_details(self):
        print(f"Movie: {self.movie_name}")
        print(f"Rating: {self.rating} / 5")


# Sample Execution
movie = Movie("Stranger", 4.8)
movie.display_movie_details()
# Out:
# Movie: Stranger
# Rating: 4.8 / 5

# %% [markdown]
# ### Problem 6: Delivery Address Manager

# %%
class Delivery:
    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address
    
    def display_delivery_details(self):
        print("Delivery Details")
        print(f"Customer: {self.customer_name}")
        print(f"Address: {self.address}")


# Sample Execution
delivery = Delivery("Gandhi", "Karnataka")
delivery.display_delivery_details()
# Out:
# Delivery Details
# Customer: Gandhi
# Address: Karnataka
